# %% [markdown]
# # Ariel Signorelli - Markdown Practice

# %% [markdown]
# ### Brief Introduction
# My name is Ariel Signorelli, and I am a Finance and Accounting student at Bellarmine University. I am interested in coding because of how AI has reached the world, and how it has been changing the way are lives have been formed with it constantly. I am excited to learn how programming can be applied Finance and Accounting and other areas of business.

# %% [markdown]
# - Attend lectures and participate in class activities
# - Complete assigned readings and course modules
# - Complete programming assignments
# - Practice coding and problem-solving exercises
# - Submit assignments through Moodle
# - Work on projects and assessments

# %% [markdown]
# 1. Introduction to Programming and Python
# 2. Variables, Data Types, and Expressions
# 3. Input, Output, and Basic Operations
# 4. Conditional Statements
# 5. Loops and Repetition
# 6. Functions and Modular Programming
# 7. Lists, Tuples, and Dictionaries
# 8. Files and Data Processing
# 9. Data Analysis and Visualization
# 10. Introduction to Advanced Python Applications

# %% [markdown]
# The primary language I will learn about in this course is **Python**.

# %% [markdown]
# I am using *Anaconda and Jupyter Notebook* to create and edit my .ipynb file.

# %% [markdown]
# Today I worked on my coursework and `created my first Markdown practice notebook`.

# %% [markdown]
# [Text you want displayed](website URL)
# [Visit my GitHub account](https://github.com/)
# [Visit my GitHub account](https://github.com/Arielsignorelli)

# %% [markdown]
# ![Bellarmine University Logo](!(bellarmine_logo.png))

# %% [markdown]
# In this Markdown practice, I learned how to use different Markdown formatting tools in Jupyter Notebook. I practiced creating headings, bullet lists, ordered lists, bold and italic text, highlighted text, hyperlinks, and images. I also learned how Markdown cells can be used to organize and present information clearly in a notebook. These skills will help me create cleaner and more professional coding assignments throughout the course.
